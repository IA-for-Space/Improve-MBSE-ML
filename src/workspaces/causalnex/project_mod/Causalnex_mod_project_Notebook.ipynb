# %%
import pandas as pd
import warnings
from causalnex.structure import StructureModel
from IPython.display import Image
from causalnex.plots import plot_structure, NODE_STYLE, EDGE_STYLE
import CausalnexDataset as cd


file = '../../../datasets/preprocess_mars_express/MarsExpressPower/marsexpress_dataset.csv'
a = cd.CausalnexDataset(dataset=file, delimiter_char=",", columns_to_drop=["ut_ms"], dropna=True, threshold=0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\causalnex\structure\notears.py:436: UserWarning: Failed to converge. Consider increasing max_iter.
#   warnings.warn("Failed to converge. Consider increasing max_iter.")

# %%
#Convertimos la matriz de adyancencia del grafo en un dataframe. Nos quedamos solo con relaciones de NPWD
nodes = a.get_all_nodes()
edges = a.get_all_edges()

npwd_nodes = [x for x in nodes if "NPWD" in x]

a.edges_to_dataframe(specific_nodes=npwd_nodes)
# Out:
#         source    target        weight
# 0     NPWD2372  NPWD2401  2.812105e-21
# 1     NPWD2372  NPWD2402  2.789904e-19
# 2     NPWD2372  NPWD2451  1.504226e-18
# 3     NPWD2372  NPWD2471  1.173958e-21
# 4     NPWD2372  NPWD2472  2.821976e-21
# ...        ...       ...           ...
# 2882    WARMUP  NPWD2852  5.280404e-22
# 2883    WARMUP  NPWD2871  5.305140e-22
# 2884    WARMUP  NPWD2872  7.543107e-22
# 2885    WARMUP  NPWD2881  5.502161e-20
# 2886    WARMUP  NPWD2882  3.418769e-21
#
# [2887 rows x 3 columns]

# %%
# Obtenemos los datos estadísticos de la matriz de adyancencia para planear un cribado de las relaciones espurias y menos relevantes
a.get_edges_data(specific_nodes=npwd_nodes)
# Out:
#              weight
# count  2.887000e+03
# mean   7.968867e-11
# std    1.056396e-09
# min    1.455402e-26
# 25%    2.499693e-21
# 50%    6.134197e-20
# 75%    1.674868e-18
# max    3.897610e-08

# %%
# Aunque la media no es un valor muy representativo por quedar muy por encima de los tres cuartiles, la elegiremos en este caso para compensar la gran cantidad de pesos demasiado pequeños.
# Utilizaremos esta media para quedarnos solo con aquellos nodos con pesos que la superen y utilizarla como umbral de pesos en el grafo. 
mean = 9.972310e-11
a.reset_threshold(mean)
viz = a.get_graph(specific_nodes=npwd_nodes)

Image(viz.draw(format="png"))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\causalnex\structure\notears.py:436: UserWarning: Failed to converge. Consider increasing max_iter.
#   warnings.warn("Failed to converge. Consider increasing max_iter.")
# Run Image(result.draw(format='png')) to draw the graph
# C:\ProgramData\Anaconda3\lib\site-packages\pygraphviz\agraph.py:1400: RuntimeWarning: Warning: node 'NPWD2372', graph '' size too small for label
# Warning: node 'sunmars_km', graph '' size too small for label
# Warning: node 'earthmars_km', graph '' size too small for label
# Warning: node 'NPWD2402', graph '' size too small for label
# Warning: node 'NPWD2451', graph '' size too small for label
# Warning: node 'NPWD2491', graph '' size too small for label
# Warning: node 'NPWD2501', graph '' size too small for label
# Warning: node 'NPWD2531', graph '' size too small for label
# Warning: node 'NPWD2532', graph '' size too small for label
# Warning: node 'NPWD2551', graph '' size too small for label
# Warning: node 'NPWD2552', graph '' size too small for label
# Warning: node 'NPWD2561', graph '' size too small for label
# Warning: node 'NPWD2562', graph '' size too small for label
# Warning: node 'NPWD2721', graph '' size too small for label
# Warning: node 'NPWD2722', graph '' size too small for label
# Warning: node 'NPWD2742', graph '' size too small for label
# Warning: node 'NPWD2771', graph '' size too small for label
# Warning: node 'NPWD2791', graph '' size too small for label
# Warning: node 'NPWD2802', graph '' size too small for label
# Warning: node 'NPWD2821', graph '' size too small for label
# Warning: node 'NPWD2851', graph '' size too small for label
# Warning: node 'NPWD2881', graph '' size too small for label
# Warning: node 'NPWD2882', graph '' size too small for label
#
#   warnings.warn(b"".join(errors).decode(self.encoding), RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\pygraphviz\agraph.py:1400: RuntimeWarning: Warning: node 'NPWD2372', graph '' size too small for label
# Warning: node 'sunmars_km', graph '' size too small for label
# Warning: node 'earthmars_km', graph '' size too small for label
# Warning: node 'NPWD2402', graph '' size too small for label
# Warning: node 'NPWD2451', graph '' size too small for label
# Warning: node 'NPWD2491', graph '' size too small for label
# Warning: node 'NPWD2532', graph '' size too small for label
# Warning: node 'NPWD2551', graph '' size too small for label
# Warning: node 'NPWD2561', graph '' size too small for label
# Warning: node 'NPWD2562', graph '' size too small for label
# Warning: node 'NPWD2721', graph '' size too small for label
# Warning: node 'NPWD2722', graph '' size too small for label
# Warning: node 'NPWD2771', graph '' size too small for label
# Warning: node 'NPWD2791', graph '' size too small for label
# Warning: node 'NPWD2802', graph '' size too small for label
# Warning: node 'NPWD2851', graph '' size too small for label
# Warning: node 'NPWD2881', graph '' size too small for label
# Warning: node 'NPWD2531', graph '' size too small for label
# Warning: node 'NPWD2501', graph '' size too small for label
# Warning: node 'NPWD2552', graph '' size too small for label
# Warning: node 'NPWD2742', graph '' size too small for label
# Warning: node 'NPWD2821', graph '' size too small for label
# Warning: node 'NPWD2882', graph '' size too small for label
#
#   warnings.warn(b"".join(errors).decode(self.encoding), RuntimeWarning)

# %%
# Es difícil de imaginar cómo las corrientes NPWD pueden influir en la distancia de marte al sol y a la tierra. Nos quedamos solo con relaciones de NPWD a sunmars_km y earthmars_km
# Primero seleccionamos estas aristas del grafo en el dataframe y después las descartamos en nuestro objeto de CausalnexDataset.
# Representamos el grafo resultante

edges = a.get_all_edges()

edges_to_remove = [(u, v) for u, v, w in edges if "NPWD" in u]

a.remove_edges(edges_to_remove)

viz = a.get_graph(specific_nodes=npwd_nodes)

Image(viz.draw(format="png"))
# Out:
# Run Image(result.draw(format='png')) to draw the graph
# C:\ProgramData\Anaconda3\lib\site-packages\pygraphviz\agraph.py:1400: RuntimeWarning: Warning: node 'NPWD2372', graph '' size too small for label
# Warning: node 'NPWD2402', graph '' size too small for label
# Warning: node 'NPWD2451', graph '' size too small for label
# Warning: node 'NPWD2491', graph '' size too small for label
# Warning: node 'NPWD2531', graph '' size too small for label
# Warning: node 'NPWD2532', graph '' size too small for label
# Warning: node 'NPWD2551', graph '' size too small for label
# Warning: node 'NPWD2561', graph '' size too small for label
# Warning: node 'NPWD2562', graph '' size too small for label
# Warning: node 'NPWD2721', graph '' size too small for label
# Warning: node 'NPWD2722', graph '' size too small for label
# Warning: node 'NPWD2771', graph '' size too small for label
# Warning: node 'NPWD2791', graph '' size too small for label
# Warning: node 'NPWD2802', graph '' size too small for label
# Warning: node 'NPWD2851', graph '' size too small for label
# Warning: node 'NPWD2881', graph '' size too small for label
# Warning: node 'sunmars_km', graph '' size too small for label
# Warning: node 'earthmars_km', graph '' size too small for label
#
#   warnings.warn(b"".join(errors).decode(self.encoding), RuntimeWarning)
